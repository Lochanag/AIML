# %% [markdown]
# <a href="https://colab.research.google.com/github/Lochanag/AIML/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv("/content/158cs22025.csv")
data.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6702.000000          6701.000000    6699.000000
# mean     33.620859             8.094687  115326.964771
# std       7.614633             6.059003   52786.183911
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
data.tail()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   float64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
data = pd.read_csv("/content/158cs22025.csv")
x = data[['Age', 'Years of Experience', 'Salary']]
y = data['Age']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
rf_regressor = RandomForestRegressor(n_estimators=100)
x_train.dropna(inplace=True)
y_train = y_train[x_train.index]
rf_regressor.fit(x_train, y_train)
x_test.dropna(inplace=True)
y_test = y_test[x_test.index]
y_pred = rf_regressor.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("Mean Squared Error:", {mse})
print("root mean squared error", {rmse})
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Age")
plt.ylabel("Predicted Age")
plt.title("Actual vs Predicted Age")
plt.show()
# Out:
# Mean Squared Error: {9.043348281016348e-06}
# root mean squared error {0.003007216034975929}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
data = pd.read_csv("/content/158cs22025.csv")
x = data[['Age', 'Years of Experience', 'Salary']]
y = data['Age']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
svr = SVR(kernel='linear')
x_train.dropna(inplace=True)
y_train = y_train[x_train.index]
svr.fit(x_train, y_train)
x_test.dropna(inplace=True)
y_test = y_test[x_test.index]
y_pred = svr.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("Mean Squared Error:", {mse})
print("root mean squared error", {rmse})
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Age")
plt.ylabel("Predicted Age")
plt.title("Actual vs Predicted Age")
plt.show()
# Out:
# Mean Squared Error: {2410930106.959793}
# root mean squared error {49101.22306989708}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.impute import SimpleImputer
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
data = pd.read_csv("/content/158cs22025.csv")
x = data.drop(['Age'], axis=1)
y = data['Salary']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
imputer_cat = SimpleImputer(strategy='most_frequent')
categorical_features = x_train.select_dtypes(include=['object']).columns
x_train[categorical_features] = imputer_cat.fit_transform(x_train[categorical_features])
x_test[categorical_features] = imputer_cat.transform(x_test[categorical_features])
imputer_num = SimpleImputer(strategy='mean')
numerical_features = x_train.select_dtypes(exclude=['object']).columns
sns.heatmap(x_train[numerical_features].corr(), annot=True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.impute import SimpleImputer
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
data = pd.read_csv("/content/158cs22025.csv")
x = data.drop(['Age'], axis=1)
y = data['Salary']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
imputer_cat = SimpleImputer(strategy='most_frequent')
categorical_features = x_train.select_dtypes(include=['object']).columns
x_train[categorical_features] = imputer_cat.fit_transform(x_train[categorical_features])
x_test[categorical_features] = imputer_cat.transform(x_test[categorical_features])
imputer_num = SimpleImputer(strategy='mean')
numerical_features = x_train.select_dtypes(exclude=['object']).columns
sns.heatmap(x_train[numerical_features].corr(), annot=True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
data = pd.read_csv("/content/158cs22025.csv")
x = data.drop(['Years of Experience'], axis=1)
y = data['Salary']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
imputer_cat = SimpleImputer(strategy='most_frequent')
categorical_features = x_train.select_dtypes(include=['object']).columns
x_train[categorical_features] = imputer_cat.fit_transform(x_train[categorical_features])
x_test[categorical_features] = imputer_cat.transform(x_test[categorical_features])
imputer_num = SimpleImputer(strategy='mean')
numerical_features = x_train.select_dtypes(exclude=['object']).columns
sns.heatmap(x_train[numerical_features].corr(), annot=True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.impute import SimpleImputer
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE
data = pd.read_csv("/content/158cs22025.csv")
x = data.drop(['Gender'], axis=1)
y = data['Age']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
imputer_cat = SimpleImputer(strategy='most_frequent')
categorical_features = x_train.select_dtypes(include=['object']).columns
x_train[categorical_features] = imputer_cat.fit_transform(x_train[categorical_features])
x_test[categorical_features] = imputer_cat.transform(x_test[categorical_features])

imputer_num = SimpleImputer(strategy='mean')
numerical_features = x_train.select_dtypes(exclude=['object']).columns
x_train[numerical_features] = imputer_num.fit_transform(x_train[numerical_features])
x_test[numerical_features] = imputer_num.transform(x_test[numerical_features])
sns.heatmap(x_train[numerical_features].corr(), annot=True)
plt.show()
